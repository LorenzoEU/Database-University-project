# %% [markdown]
# <a href="https://colab.research.google.com/github/LorenzoEU/Database-University-project/blob/main/utils/Lab1_DataSet_DataLoader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 33.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import torch
import numpy as np

# %% [markdown]
# # PyTorch Fundamentals Exercises

# %% [markdown]
# ### 2. Create a random tensor with shape `(7, 7)`.

# %%
# Import torch

# Create random tensor
x = torch.rand(7,7)

# %%
print(x)
# Out:
# tensor([[0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071],
#         [0.6297, 0.3653, 0.8513, 0.8549, 0.5509, 0.2868, 0.2063],
#         [0.4451, 0.3593, 0.7204, 0.0731, 0.9699, 0.1078, 0.8829],
#         [0.4132, 0.7572, 0.6948, 0.5209, 0.5932, 0.8797, 0.6286],
#         [0.7653, 0.1132, 0.8559, 0.6721, 0.6267, 0.5691, 0.7437],
#         [0.9592, 0.3887, 0.2214, 0.3742, 0.1953, 0.7405, 0.2529],
#         [0.2332, 0.9314, 0.9575, 0.5575, 0.4134, 0.4355, 0.7369]])

# %% [markdown]
# ### 3. Perform a matrix multiplication on the tensor from 2 with another random tensor with shape `(1, 7)` (hint: you may have to transpose the second tensor).

# %%
# Create another random tensor
y = torch.rand(1,7)

# Perform matrix multiplication

mult = torch.matmul(x,y.T)
print(mult)
# Out:
# tensor([[1.1197],
#         [1.3239],
#         [1.5975],
#         [2.0176],
#         [1.8516],
#         [1.1764],
#         [1.9380]])

# %% [markdown]
# ### 4. Set the random seed to `0` and do 2 & 3 over again.
#
# The output should be:
# ```
# (tensor([[1.8542],
#          [1.9611],
#          [2.2884],
#          [3.0481],
#          [1.7067],
#          [2.5290],
#          [1.7989]]), torch.Size([7, 1]))
# ```

# %%
# Set manual seed
torch.manual_seed(0)


# Create two random tensors
x = torch.rand(7,7)
y = torch.rand(1,7)

# Matrix multiply tensors

mult = torch.matmul(x,y.T)
print(mult)
# Out:
# tensor([[1.8542],
#         [1.9611],
#         [2.2884],
#         [3.0481],
#         [1.7067],
#         [2.5290],
#         [1.7989]])

# %% [markdown]
# ### 5. Speaking of random seeds, we saw how to set it with `torch.manual_seed()` but is there a GPU equivalent? (hint: you'll need to look into the documentation for `torch.cuda` for this one)
#   * If there is, set the GPU random seed to `1234`.

# %%
# Set random seed on the GPU
torch.cuda.seed()

# %% [markdown]
# ### 6. Create two random tensors of shape `(2, 3)` and send them both to the GPU (you'll need access to a GPU for this). Set `torch.manual_seed(1234)` when creating the tensors (this doesn't have to be the GPU random seed). The output should be something like:
#
# ```
# Device: cuda
# (tensor([[0.0290, 0.4019, 0.2598],
#          [0.3666, 0.0583, 0.7006]], device='cuda:0'),
#  tensor([[0.0518, 0.4681, 0.6738],
#          [0.3315, 0.7837, 0.5631]], device='cuda:0'))
# ```

# %%
# Set random seed
torch.manual_seed(1234)
# Check for access to GPU
if torch.cuda.is_available():
  # Create two random tensors on GPU
  X = torch.rand(2,3)
  Y = torch.rand(2,3)
else:
  print("No GPU")

# %% [markdown]
# ### 7. Perform a matrix multiplication on the tensors you created in 6 (again, you may have to adjust the shapes of one of the tensors).
#
# The output should look like:
# ```
# (tensor([[0.3647, 0.4709],
#          [0.5184, 0.5617]], device='cuda:0'), torch.Size([2, 2]))
# ```

# %%
# Perform matmul on tensor_A and tensor_B
mult = torch.matmul(X,Y.T)
print(mult)
# Out:
# tensor([[0.8787, 0.9028],
#         [0.6804, 0.8410]], dtype=torch.float64)

# %% [markdown]
# ### 8. Find the maximum and minimum values of the output of 7.

# %%
# Find max
max = torch.max(mult)
print(max)
# Find min
min = torch.min(mult)
print(min)
# Out:
# tensor(0.9028, dtype=torch.float64)
# tensor(0.6804, dtype=torch.float64)

# %%
max_row = torch.max(mult,dim=0)
print(max_row)
# Out:
# torch.return_types.max(
# values=tensor([0.8787, 0.9028], dtype=torch.float64),
# indices=tensor([0, 0]))

# %% [markdown]
# ### 9. Find the maximum and minimum index values of the output of 7.

# %%
# Find arg max
argmax = torch.argmax(mult)
print(argmax)

# Find arg min
argmin = torch.argmin(mult)
print(argmin)
# Out:
# tensor(1)
# tensor(2)

# %% [markdown]
# ### 10. Make a random tensor with shape `(1, 1, 1, 10)` and then create a new tensor with all the `1` dimensions removed to be left with a tensor of shape `(10)`. Set the seed to `7` when you create it and print out the first tensor and it's shape as well as the second tensor and it's shape.
#
# The output should look like:
#
# ```
# tensor([[[[0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297,
#            0.3653, 0.8513]]]]) torch.Size([1, 1, 1, 10])
# tensor([0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297, 0.3653,
#         0.8513]) torch.Size([10])
# ```

# %%
# Set seed
torch.manual_seed(7)

# Create random tensor
A = torch.rand(1,1,1,10)

# Remove single dimensions
B = A.squeeze()
# Print out tensors and their shapes
print(A, A.shape)
print(B, B.shape)
# Out:
# tensor([[[[0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297,
#            0.3653, 0.8513]]]]) torch.Size([1, 1, 1, 10])
# tensor([0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297, 0.3653,
#         0.8513]) torch.Size([10])

# %% [markdown]
# # **PARTE 2**

# %% [markdown]
# ### PyTorch DataLoader Exercises
#
# Welcome to the PyTorchDataLoader exercise template notebook.
#
# There are several questions in this notebook and it's your goal to answer them by writing Python and PyTorch code.
#
# > **Note:** There may be more than one solution to each of the exercises, don't worry too much about the *exact* right answer. Try to write some code that works first and then improve it if you can.

# %%
# Import necessary libraries
import os
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
import requests
from zipfile import ZipFile
from io import BytesIO
import numpy as np

# Define the path to the dataset
dataset_path = 'http://cs231n.stanford.edu/tiny-imagenet-200.zip'  # Replace with the path to your dataset

# Send a GET request to the URL
response = requests.get(dataset_path)
# Check if the request was successful
if response.status_code == 200:
    # Open the downloaded bytes and extract them
    with ZipFile(BytesIO(response.content)) as zip_file:
        zip_file.extractall('/dataset')
    print('Download and extraction complete!')
# Out:
# Download and extraction complete!

# %%
# Define transformations for the dataset
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])])

# Load the dataset
tiny_imagenet_dataset_train = ImageFolder(root='/dataset/tiny-imagenet-200/train', transform=transform)
tiny_imagenet_dataset_test = ImageFolder(root='/dataset/tiny-imagenet-200/test', transform=transform)

# Create a DataLoader
dataloader_train = DataLoader(tiny_imagenet_dataset_train, batch_size=128, shuffle=True)
dataloader_test = DataLoader(tiny_imagenet_dataset_test, batch_size=128, shuffle=False)

# Determine the number of classes and samples
num_classes = len(tiny_imagenet_dataset_train.classes)
num_samples = len(tiny_imagenet_dataset_train)

print(f'Number of classes: {num_classes}')
print(f'Number of samples: {num_samples}')

# Function to denormalize image for visualization
def denormalize(image):
    image = image.to('cpu').numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = image * std + mean
    image = np.clip(image, 0, 1)
    return image

# Visualize one example for each class for 10 classes
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
classes_sampled = []
found_classes = 0

for i, (inputs, classes) in enumerate(dataloader_train):
  for idx, classe in enumerate(classes): # Use idx for index and classe for the class label
    if classe not in classes_sampled:
        classes_sampled.append(classe)
        image = denormalize(inputs[idx]) # Use idx to access the correct image from the batch
        row = found_classes // 5
        col = found_classes % 5
        axes[row, col].imshow(image)
        axes[row, col].set_title(f"Class: {classe.item()}") # Use .item() to get the class value as an integer
        axes[row, col].axis('off')
        found_classes += 1
        if found_classes == 10:
            break
  if found_classes == 10:
    break
plt.show()
# Out:
# Number of classes: 200
# Number of samples: 100000

# %%
import matplotlib.pyplot as plt

# Function to denormalize image for visualization
def denormalize(image):
    image = image.to('cpu').numpy().transpose((1, 2, 0))
    mean = np.array([0.53,0.23,0.53])
    std = np.array([0.223,0.42,0.64])
    image = image * std + mean
    image = np.clip(image, 0, 1)
    return image

# Create a figure and axes for the subplots
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
images_shown = 0

# Iterate through the dataloader to find images of class 80
for i, (inputs, classes) in enumerate(dataloader_train):
    for idx, classe in enumerate(classes):
        if classe.item() == 26:  # Check if the image belongs to class 80
            image = denormalize(inputs[idx])  # Denormalize the image for visualization
            row = images_shown // 5  # Calculate the row index for the subplot
            col = images_shown % 5  # Calculate the column index for the subplot
            axes[row, col].imshow(image)  # Display the image in the subplot
            axes[row, col].imshow(image)
            axes[row, col].set_title(f"Class: {classe.item()}") # Use .item() to get the class value as an integer
            axes[row, col].axis('off')
            images_shown += 1  # Increment the counter for displayed images
            if images_shown == 10:  # Check if 10 images have been displayed
                break  # Exit the inner loop if 10 images have been shown
    if images_shown == 10:  # Check if 10 images have been displayed
        break  # Exit the outer loop if 10 images have been shown

plt.show()  # Display the plot with the images
